# %% [markdown]
# # Abalone Case Study Project:

# %% [markdown]
# ### Problem Statement:
#
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# ### Attribute Information:
#
# Given is the attribute name, attribute type, the measurement unit and a brief description. The number of rings is the value to predict.
#
# ###### Name / Data Type / Measurement Unit / Description
#
# 1. Sex / nominal / -- / M, F, and I (infant)
# 2. Length / continuous / mm / Longest shell measurement
# 3. Diameter / continuous / mm / perpendicular to length
# 4. Height / continuous / mm / with meat in shell
# 5. Whole weight / continuous / grams / whole abalone
# 6. Shucked weight / continuous / grams / weight of meat
# 7. Viscera weight / continuous / grams / gut weight (after bleeding)
# 8. Shell weight / continuous / grams / after being dried
# 9. Rings / integer / -- / +1.5 gives the age in years
#
# You have to predict the rings of each abalone which will lead us to the age of that abalone.

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("https://raw.githubusercontent.com/Shrey99saha/Datatrained_Projects/main/Projects%204/AbaloneDS.csv")

# %%
dataframe
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
dataframe.shape
# Out:
# (4177, 9)

# %%
dataframe.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
dataframe.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
dataframe.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sqrt
import scipy.stats as stats

# %% [markdown]
# ### Count Plot

# %%
plt.figure(figsize=(10,7))
sns.countplot(x ='Sex', data = dataframe)
plt.xlabel('Number of categories in the Sex column')
plt.ylabel('Count of Rows present in the dataset')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
index=0
labels = dataframe['Rings']
features = dataframe.drop(['Rings', 'Sex'], axis=1)

for col in features.items():
    plt.figure(figsize=(10,10))
    sns.barplot(x=labels, y=col[index], data=dataframe, color="r")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plot

# %%
index = 0
for col in features.items():
    plt.figure(figsize=(10,10))
    sns.boxplot(x=labels, y=col[index], data=dataframe, color="b")
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %% [markdown]
# ### Distribution Plot

# %%
for col, value in features.items():
    plt.figure(figsize=(5,5))
    sns.distplot(value, hist=False, color="m", kde_kws={"shade": True})
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.rcParams['figure.figsize'] = (10,10)
dataframe.hist(bins=30, color='g', density=True, label='Value', grid=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(dataframe)
plt.show()

# %% [markdown]
# # Correlation using a Heatmap

# %%
dfcorr = (dataframe.corr())
plt.figure(figsize=(15,15))
sns.heatmap(dfcorr, vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', annot_kws={'size':10}, cmap="cool_r")
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Encoding

# %%
dataframe = pd.get_dummies(dataframe)
dataframe
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
# ...

# %% [markdown]
# # Outlier removal

# %%
from scipy.stats import zscore

# %%
dataframe.shape
# Out:
# (4177, 11)

# %%
# Z score method

z=np.abs(zscore(dataframe))
threshold=3
np.where(z>3)

dataframe=dataframe[(z<3).all(axis=1)]
dataframe
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
# ...

# %%
dataframe.shape
# Out:
# (4027, 11)

# %%
# Percentage of Data Loss

data_loss=(4177-4027)/4177*100 
# 4177 (number of rows in the original dataframe) and 4027 (number of rows after outlier removal)
data_loss
# Out:
# 3.5910940866650707

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# # Splitting the dataset into 2 variables namely 'X' and 'Y' for feature and label

# %%
X = dataframe.drop('Rings', axis=1)
Y = dataframe['Rings']

# %% [markdown]
# # Variance Inflation Factor(VIF)

# %%
vif_data = pd.DataFrame()
vif_data["Features"]=X.columns
vif_data["VIF Value"]=[variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
print(vif_data)
# Out:
#          Features   VIF Value
# 0          Length   39.165074
# 1        Diameter   40.852649
# 2          Height    6.591310
# 3    Whole weight  108.277063
# 4  Shucked weight   28.666881
# 5  Viscera weight   17.151153
# 6    Shell weight   23.503036
# 7           Sex_F   27.011268
# 8           Sex_I   24.955912
# 9           Sex_M   30.318435

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X # Displaying all the features after applying scaling technique to avoid bias output
# Out:
#         Length  Diameter    Height  Whole weight  Shucked weight  \
# 0    -0.569368 -0.420274 -1.166207     -0.633156       -0.603733
# 1    -1.475358 -1.463127 -1.301806     -1.265644       -1.209410
# 2     0.077768  0.153294 -0.081420     -0.275805       -0.448680
# 3    -0.698795 -0.420274 -0.352617     -0.628771       -0.647342
# 4    -1.647928 -1.567412 -1.573003     -1.310587       -1.257865
# ...        ...       ...       ...           ...             ...
# 4022  0.379764  0.466150  0.732171      0.184584        0.101275
# 4023  0.595476  0.361865 -0.081420      0.357779        0.435609
# 4024  0.681761  0.726863  1.816959      0.818169        0.854737
# 4025  0.897473  0.831148  0.325376      0.639493        0.881387
# 4026  1.630893  1.561145  1.545762      2.511746        2.889812
#
#       Viscera weight  Shell weight     Sex_F     Sex_I     Sex_M
# 0          -0.723057     -0.630659 -0.670525 -0.699088  1.328833
# ...

# %% [markdown]
# # Creating the training and testing data sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)

# %% [markdown]
# # Machine Learning Model for Regression and Evaluation Metrics

# %%
# Regression Model Function

def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=21)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # RMSE - a lower RMSE score is better than a higher one
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score:", rmse)
    
    # R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of r2 score minus cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
# Linear Regression Model

model=LinearRegression()
reg(model, X, Y)
# Out:
# RMSE Score: 1.9427969153438613
# R2 Score: 52.424787948299134
# Cross Validation Score: 43.69409878832823
# R2 Score - Cross Validation Score is 8.7306891599709

# %%
# Support Vector Regression

model=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
reg(model, X, Y)
# Out:
# RMSE Score: 2.0264575321905616
# R2 Score: 48.23920527341261
# Cross Validation Score: 43.35139317049461
# R2 Score - Cross Validation Score is 4.887812102917998

# %%
# Decision Tree Regressor

model=DecisionTreeRegressor(criterion="poisson", random_state=111)
reg(model, X, Y)
# Out:
# RMSE Score: 2.6188854106364916
# R2 Score: 13.55121083694848
# Cross Validation Score: -7.562509918973066
# R2 Score - Cross Validation Score is 21.113720755921545

# %%
# Random Forest Regressor

model=RandomForestRegressor(max_depth=2, max_features="sqrt")
reg(model, X, Y)
# Out:
# RMSE Score: 2.2252490884846696
# R2 Score: 37.58583197128183
# Cross Validation Score: 24.5311923885693
# R2 Score - Cross Validation Score is 13.054639582712529

# %%
# K Neighbors Regressor

KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model, X, Y)
# Out:
# RMSE Score: 2.227138681521888
# R2 Score: 37.4797877070178
# Cross Validation Score: 24.71237875048426
# R2 Score - Cross Validation Score is 12.76740895653354

# %%
# SGD Regressor

model=SGDRegressor(penalty='l1', max_iter=2000, learning_rate='optimal')
reg(model, X, Y)
# Out:
# RMSE Score: 1.9851609496999938
# R2 Score: 50.32734549429625
# Cross Validation Score: 29.489427052387473
# R2 Score - Cross Validation Score is 20.83791844190878

# %%
# Gradient Boosting Regressor

model=GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
reg(model, X, Y)
# Out:
# RMSE Score: 2.9736158820612126
# R2 Score: -11.453999462080235
# Cross Validation Score: -46.69995153729978
# R2 Score - Cross Validation Score is 35.24595207521955

# %%
# Ada Boost Regressor

model=AdaBoostRegressor(n_estimators=300, learning_rate=1.05, random_state=42)
reg(model, X, Y)
# Out:
# RMSE Score: 2.246565116708978
# R2 Score: 36.384353592113854
# Cross Validation Score: 14.54849164429008
# R2 Score - Cross Validation Score is 21.835861947823773

# %%
# Extra Trees Regressor

model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
reg(model, X, Y)
# Out:
# RMSE Score: 1.9072049706961596
# R2 Score: 54.15197185116716
# Cross Validation Score: 45.867852117903006
# R2 Score - Cross Validation Score is 8.284119733264156

# %% [markdown]
# # Hyper parameter tuning

# %%
# Choosing Support Vector Regression

fmod_param = {'kernel' : ['poly', 'sigmoid', 'rbf'], 
              'C' : [2.0, 3.0, 4.0], 
              'gamma' : ['scale', 'auto'], 
              'epsilon' : [0.2, 0.3, 0.4], 
              'shrinking' : [True, False]}

# %%
GSCV = GridSearchCV(SVR(), fmod_param, cv=5)

# %%
GSCV.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [2.0, 3.0, 4.0], 'epsilon': [0.2, 0.3, 0.4],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'sigmoid', 'rbf'],
#                          'shrinking': [True, False]})

# %%
GSCV.best_params_
# Out:
# {'C': 4.0,
#  'epsilon': 0.4,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'shrinking': True}

# %%
TrainModel = SVR(C=4.0, epsilon=0.4, gamma='scale', kernel='rbf', shrinking=True)
Classifier = TrainModel.fit(X_train, Y_train)
fmod_pred = TrainModel.predict(X_test)
fmod_r2 = r2_score(Y_test, fmod_pred, multioutput='variance_weighted')*100
print("R2 score for the Best Model is:", fmod_r2)
# Out:
# R2 score for the Best Model is: 55.62575634005215

# %% [markdown]
# # Saving the best model

# %%
import pickle

# %%
filename = "Trained_Data_2.pkl"
pickle.dump(TrainModel, open(filename, 'wb'))
